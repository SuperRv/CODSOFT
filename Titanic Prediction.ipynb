# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("D:\\CODSOFT\\titanicdata.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Handling missing values

# %%
#drop cabin column as most of the values are missing
data = data.drop('Cabin', axis=1)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
#Using the same method to add missing values in age column
data.groupby(['Pclass', 'Sex']).mean()
# Out:
#                PassengerId  Survived        Age     SibSp     Parch  \
# Pclass Sex
# 1      female   469.212766  0.968085  34.611765  0.553191  0.457447
#        male     455.729508  0.368852  41.281386  0.311475  0.278689
# 2      female   443.105263  0.921053  28.722973  0.486842  0.605263
#        male     447.962963  0.157407  30.740707  0.342593  0.222222
# 3      female   399.729167  0.500000  21.750000  0.895833  0.798611
#        male     455.515850  0.135447  26.507589  0.498559  0.224784
#
#                      Fare
# Pclass Sex
# 1      female  106.125798
#        male     67.226127
# 2      female   21.970121
#        male     19.741782
# 3      female   16.118810
#        male     12.661633

# %%
data['Age'] = round(data['Age'].fillna(data.groupby(['Pclass', 'Sex'])['Age'].transform('mean')),2)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00      1
# 2                               Heikkinen, Miss. Laina  female  26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1
# 4                             Allen, Mr. William Henry    male  35.00      0
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
data.groupby('Embarked').count()
# Out:
#           PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Embarked
# C                 168       168     168   168  168  168    168    168     168
# Q                  77        77      77    77   77   77     77     77      77
# S                 644       644     644   644  644  644    644    644     644
#
#           Fare
# Embarked
# C          168
# Q           77
# S          644

# %%
# Since more than 50% of passangers have embarked from 'S' we will fill 2 missing values with 'S'
data['Embarked'].fillna('S', inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
sns.countplot(data['Survived'])
plt.title('No of people survived')
# Out:
# C:\additionalPackages\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'No of people survived')

# %%
bar_data = data.groupby(['Pclass', 'Sex', 'Survived']).count()

# %%
bar_data
# Out:
#                         PassengerId  Name  Age  SibSp  Parch  Ticket  Fare  \
# Pclass Sex    Survived
# 1      female 0                   3     3    3      3      3       3     3
#               1                  91    91   91     91     91      91    91
#        male   0                  77    77   77     77     77      77    77
#               1                  45    45   45     45     45      45    45
# 2      female 0                   6     6    6      6      6       6     6
#               1                  70    70   70     70     70      70    70
#        male   0                  91    91   91     91     91      91    91
#               1                  17    17   17     17     17      17    17
# 3      female 0                  72    72   72     72     72      72    72
#               1                  72    72   72     72     72      72    72
#        male   0                 300   300  300    300    300     300   300
# ...

# %%
bar_data = bar_data['PassengerId'].unstack()

# %%
bar_data
# Out:
# Survived         0   1
# Pclass Sex
# 1      female    3  91
#        male     77  45
# 2      female    6  70
#        male     91  17
# 3      female   72  72
#        male    300  47

# %%
bar_data.plot(kind = 'bar')
plt.title('Survival Number based on class and sex')
# Out:
# Text(0.5, 1.0, 'Survival Number based on class and sex')

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
ax = data['Age'][data['Sex']=='male'].plot.kde( label='Male')
data['Age'][data['Sex']=='female'].plot.kde(ax = ax, label='Female')
ax.set_xlabel('Age')
ax.set_ylabel('Density')
ax.set_title('Distribution by Age')
ax.legend()

# %% [markdown]
# ## Model Training and Building

# %% [markdown]
# We have 2 coulmn which can be converted to numerical values i.e. Sex and Embarked

# %% [markdown]
# Sex - Female-0, Male-1<br>
# Embarked - C-0, Q-1, S-2

# %%
#Using Label Encoding for the same
from sklearn.preprocessing import LabelEncoder

# %%
data['Sex'].head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: Sex, dtype: object

# %%
data['Sex'] = LabelEncoder().fit_transform(data['Sex'])

# %%
data['Sex'].head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: Sex, dtype: int32

# %%
data['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
data['Embarked'] = LabelEncoder().fit_transform(data['Embarked'])

# %%
data['Embarked']
# Out:
# 0      2
# 1      0
# 2      2
# 3      2
# 4      2
#       ..
# 886    2
# 887    2
# 888    2
# 889    0
# 890    1
# Name: Embarked, Length: 891, dtype: int32

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.00      1
# 2                               Heikkinen, Miss. Laina    0  26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.00      1
# 4                             Allen, Mr. William Henry    1  35.00      0
# ..                                                 ...  ...    ...    ...
# ...

# %%
#Splitting the data into training and testing set
from sklearn.model_selection import train_test_split

# %%
X = data.drop(columns=['PassengerId', 'Survived', 'Name', 'Ticket'], axis =1)
Y = data['Survived']

# %%
X
# Out:
#      Pclass  Sex    Age  SibSp  Parch     Fare  Embarked
# 0         3    1  22.00      1      0   7.2500         2
# 1         1    0  38.00      1      0  71.2833         0
# 2         3    0  26.00      0      0   7.9250         2
# 3         1    0  35.00      1      0  53.1000         2
# 4         3    1  35.00      0      0   8.0500         2
# ..      ...  ...    ...    ...    ...      ...       ...
# 886       2    1  27.00      0      0  13.0000         2
# 887       1    0  19.00      0      0  30.0000         2
# 888       3    0  21.75      1      2  23.4500         2
# 889       1    1  26.00      0      0  30.0000         0
# 890       3    1  32.00      0      0   7.7500         1
#
# [891 rows x 7 columns]

# %%
Y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=5)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (891, 7) (712, 7) (179, 7)

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
lr_model = LogisticRegression().fit(X_train,Y_train)
lr_pred = lr_model.predict(X_test)
con = classification_report(Y_test, lr_pred)
print(con)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86       111
#            1       0.80      0.71      0.75        68
#
#     accuracy                           0.82       179
#    macro avg       0.82      0.80      0.81       179
# weighted avg       0.82      0.82      0.82       179

# %% [markdown]
# ## Prediction

# %%
X.iloc[6].values
# Out:
# array([ 1.    ,  1.    , 54.    ,  0.    ,  0.    , 51.8625,  2.    ])

# %%
X.columns
# Out:
# Index(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'], dtype='object')

# %%
Y.iloc[6]
# Out:
# 0

# %%
values = pd.DataFrame(X.iloc[6].values.reshape(1,-1), columns=['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
user_pred = lr_model.predict(values)
print(user_pred)
# Out:
# [0]
